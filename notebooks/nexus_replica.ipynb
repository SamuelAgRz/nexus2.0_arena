# %% [markdown]
# # Nexus 2.0 Notebook Replica
#
# Este notebook replica una arquitectura tipo Nexus 2.0 usando:
# - Foundry / Azure OpenAI compatible endpoint
# - Power BI REST API para ejecutar DAX
# - Orquestador multiagente en Python

# %%
import sys
from pathlib import Path

root = Path.cwd().resolve().parents[0]
if str(root) not in sys.path:
    sys.path.append(str(root))

root

# %%
from src.main import build_orchestrator

semantic_context_path = str(repo_root / 'examples' / 'semantic_context_nsr_latam_cube_uat.md')
orchestrator = build_orchestrator(semantic_context_path)
print('Orchestrator listo')

# %%
question = 'What is NSR YTD by channel for Colombia?'
result = orchestrator.run(question)
result['intent']

# %%
print('--- DAX draft ---')
print(result['dax_draft'])

print('\--- DAX final ---')
print(result['dax_final'])

# %%
print(result['final_answer'])

# %%
df = result['dataframe']\n
df.head() if df is not None else 'No dataframe generated'\n
